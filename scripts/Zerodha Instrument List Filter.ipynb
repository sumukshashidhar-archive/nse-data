# %%
import pandas as pd

# %%
df = pd.read_csv('./../lists/zerodha_instrument_list.csv')

# %%
df
# Out:
#        instrument_token  exchange_token         tradingsymbol  \
# 0             552830982         2159496  EURINR21DEC81.5000CE
# 1             552830470         2159494  EURINR21DEC81.5000PE
# 2             552826374         2159478  EURINR21DEC81.7500CE
# 3             552825606         2159475  EURINR21DEC81.7500PE
# 4             552837126         2159520  EURINR21DEC82.0000CE
# ...                 ...             ...                   ...
# 84841            978945            3824             ZODJRDMKJ
# 84842           2916865           11394                  ZOTA
# 84843           7436801           29050                 ZUARI
# 84844            979713            3827             ZUARIGLOB
# 84845           4514561           17635             ZYDUSWELL
#
#                        name  last_price      expiry  strike  tick_size  \
# 0                    EURINR           0  2021-12-29   81.50     0.0025
# 1                    EURINR           0  2021-12-29   81.50     0.0025
# ...

# %%
dfx = df[df['exchange'].isin(['NSE', 'BSE'])]

# %%
dfx.head()
# Out:
#       instrument_token  exchange_token tradingsymbol name  last_price expiry  \
# 2949         245876996          960457    0001AIPL24  NaN           0    NaN
# 2950         245304324          958220     001CSSL25  NaN           0    NaN
# 2951         245303812          958218      001JAL48  NaN           0    NaN
# 2952         183046148          715024      001PSL35  NaN           0    NaN
# 2953         138992388          542939         04ABB  NaN           0    NaN
#
#       strike  tick_size  lot_size instrument_type segment exchange
# 2949     0.0       0.01        10              EQ     BSE      BSE
# 2950     0.0       0.01         1              EQ     BSE      BSE
# 2951     0.0       0.01         1              EQ     BSE      BSE
# 2952     0.0       0.01         1              EQ     BSE      BSE
# 2953     0.0       0.01         1              EQ     BSE      BSE

# %%
dfx = dfx.sort_values(by='exchange', ascending=False)

# %%
dfx = dfx.drop(columns=['last_price', 'strike', 'tick_size', 'lot_size', 'expiry', 'exchange', 'instrument_type'])

# %%
dfx = dfx.dropna()

# %%
dfx = dfx.drop_duplicates(subset=['tradingsymbol'], keep='first')
dfx = dfx.drop_duplicates(subset=['name'], keep='first')

# %%
dfx = dfx.sort_values(by='tradingsymbol')

# %%
dfx = dfx.reset_index()

# %%
dfx = dfx.drop(columns=['index'])

# %%
dfx.where(dfx['tradingsymbol'] == 'TATASTEEL').dropna()
# Out:
#       instrument_token  exchange_token tradingsymbol        name segment
# 3387          895745.0          3499.0     TATASTEEL  TATA STEEL     NSE

# %%
dfx.to_csv('./../lists/zerodha_instruments_equities.csv', index=False)
